# %%
import pandas as pd
import requests

# %%
import requests

url = "https://horse-racing.p.rapidapi.com/race/207660"

headers = {
	"x-rapidapi-key": "5f4a4bb95dmsh1d8aa956a63c7a3p16962ejsnaf245460f9c5",
	"x-rapidapi-host": "horse-racing.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'id_race': '207660', 'course': 'Newcastle', 'date': '2021-09-02 20:35:00', 'title': 'WILLIAM HILL DOUBLE YOUR ODDS RACING LEAGUE RACE THIRTY-SIX (HANDICAP) (3)', 'distance': '5f', 'age': '3', 'going': 'Standard to Slow', 'finished': '1', 'canceled': '0', 'finish_time': '59.07s', 'prize': '£25770', 'class': '3', 'horses': [{'horse': 'Saluti(IRE)', 'id_horse': '213923', 'jockey': 'Paul Mulrennan', 'trainer': 'Paul Midgley', 'age': '7', 'weight': '9-5', 'number': '4', 'last_ran_days_ago': '19', 'non_runner': '0', 'form': '46471316', 'position': '1', 'distance_beaten': '', 'owner': 'R Bradley &amp; M Hammond', 'sire': 'ACCLAMATION', 'dam': 'GREEK EASTER(IRE)', 'OR': '82', 'sp': '10', 'odds': []}, {'horse': 'Show Me Show Me', 'id_horse': '234340', 'jockey': 'Paddy Mathers', 'trainer': 'Richard Fahey', 'age': '4', 'weight': '9-85ex', 'number': '3', 'last_ran_days_ago': '7', 'non_runner': '0', 'form': '0-8471001', 'position': '2', 'distance_beaten': '1 1/4', 'owner': 'Ontoawinner 8 and Partner 4', 'sire': 'SHOWCASING', 'dam': 'SPRINGING BARONESS', 'OR': '85', 'sp': '11', 'odds': []}, {'horse': 'Faustus', 'id_horse': '247521', 'jockey': 'Robert Havlin', 'trainer': 'Robert Cowell', 'age': '3', 'weight': '9-4', 'number': '5', 'last_ran_days_ago': '35', 'non_runner': '0', 'form': '25-482312', 'position': '3', 'distance_beaten': '1', 'owner': 'Mrs Jenny Hadida', 'sire': 'MAYSON', 'dam': 'ISRAFEL', 'OR': '82', 'sp': '5', 'odds': []}, {'horse': 'Kingsholm(IRE)', 'id_horse': '237421', 'jockey': 'Jack Mitchell', 'trainer': 'James Fanshawe', 'age': '4', 'weight': '8-10', 'number': '9', 'last_ran_days_ago': '35', 'non_runner': '0', 'form': '51201-446', 'position': '4', 'distance_beaten': 'sh', 'owner': 'Qatar Racing, D.Howden &amp; D.Redvers', 'sire': 'TAGULA(IRE)', 'dam': 'FIXED GAZE(USA)', 'OR': '73', 'sp': '7.5', 'odds': []}, {'horse': 'Electric Love', 'id_horse': '252385', 'jockey': 'Laura Pearson', 'trainer': 'Tom Clover', 'age': '3', 'weight': '8-9', 'number': '10', 'last_ran_days_ago': '7', 'non_runner': '0', 'form': '2241123', 'position': '5', 'distance_beaten': 'hd', 'owner': 'Joseph Barton &amp; Partner', 'sire': 'EQUIANO(FR)', 'dam': 'ELECTRIC FEEL', 'OR': '73', 'sp': '7', 'odds': []}, {'horse': 'Spoof', 'id_horse': '216935', 'jockey': 'Saffie Osborne', 'trainer': 'Charles Hills', 'age': '6', 'weight': '9-9', 'number': '2', 'last_ran_days_ago': '35', 'non_runner': '0', 'form': '17-662175', 'position': '6', 'distance_beaten': '1 1/4', 'owner': 'Gary and Linnet Woodward', 'sire': 'POETS VOICE', 'dam': 'FILONA(IRE)', 'OR': '86', 'sp': '19', 'odds': []}, {'horse': 'Kool Moe Dee(IRE)', 'id_horse': '244169', 'jockey': 'Hayley Turner', 'trainer': 'Richard Hannon', 'age': '3', 'weight': '8-9', 'number': '11', 'last_ran_days_ago': '7', 'non_runner': '0', 'form': '54467267', 'position': '7', 'distance_beaten': 'sh', 'owner': 'Mr K. Sohi', 'sire': 'MEHMAS(IRE)', 'dam': 'SENADORA(GER)', 'OR': '73', 'sp': '9', 'odds': []}, {'horse': 'Huraiz(IRE)', 'id_horse': '238473', 'jockey': 'Marco Ghiani', 'trainer': 'Stuart Williams', 'age': '4', 'weight': '9-10', 'number': '1', 'last_ran_days_ago': '14', 'non_runner': '0', 'form': '32670455', 'position': '8', 'distance_beaten': '3 1/4', 'owner': 'Mr Hamdan Al Maktoum', 'sire': 'SEPOY(AUS)', 'dam': 'SAMAAH(IRE)', 'OR': '87', 'sp': '6.5', 'odds': []}, {'horse': 'Centurion Song(IRE)', 'id_horse': '237064', 'jockey': 'Martin Dwyer', 'trainer': 'Brian Meehan', 'age': '4', 'weight': '8-13', 'number': '7', 'last_ran_days_ago': '35', 'non_runner': '0', 'form': '2U471880', 'position': '9', 'distance_beaten': 'nk', 'owner': 'Mr B. J. Meehan', 'sire': 'CAMACHO', 'dam': 'NEW MUSIC(IRE)', 'OR': '76', 'sp': '81', 'odds': []}, {'horse': 'Bowling Russian(IRE)', 'id_horse': '237244', 'jockey': 'Pat Cosgrave', 'trainer': 'George Baker', 'age': '4', 'weight': '9-3', 'number': '6', 'last_ran_days_ago': '6', 'non_runner': '0', 'form': '417-76998', 'position': '10', 'distance_beaten': '2', 'owner': 'Mr P. Bowden', 'sire': 'LOP ...

# %%
pd.DataFrame(response.json()['horses'])
# Out:
#                    horse id_horse          jockey               trainer age  \
# 0            Saluti(IRE)   213923  Paul Mulrennan          Paul Midgley   7
# 1        Show Me Show Me   234340   Paddy Mathers         Richard Fahey   4
# 2                Faustus   247521   Robert Havlin         Robert Cowell   3
# 3         Kingsholm(IRE)   237421   Jack Mitchell        James Fanshawe   4
# 4          Electric Love   252385   Laura Pearson            Tom Clover   3
# 5                  Spoof   216935  Saffie Osborne         Charles Hills   6
# 6      Kool Moe Dee(IRE)   244169   Hayley Turner        Richard Hannon   3
# 7            Huraiz(IRE)   238473    Marco Ghiani       Stuart Williams   4
# 8    Centurion Song(IRE)   237064    Martin Dwyer          Brian Meehan   4
# 9   Bowling Russian(IRE)   237244    Pat Cosgrave          George Baker   4
# 10      The Princes Poet   246725   Georgia Dobie  Eve Johnson Houghton   3
#
#     weight number last_ran_days_ago non_runner       form position  \
# 0      9-5      4                19          0   46471316        1
# 1   9-85ex      3                 7          0  0-8471001        2
# 2      9-4      5                35          0  25-482312        3
# 3     8-10      9                35          0  51201-446        4
# 4      8-9     10                 7          0    2241123        5
# 5      9-9      2                35          0  17-662175        6
# 6      8-9     11                 7          0   54467267        7
# 7     9-10      1                14          0   32670455        8
# 8     8-13      7                35          0   2U471880        9
# 9      9-3      6                 6          0  417-76998       10
# 10    8-10      8                 7          0  8-2515814       11
#
#    distance_beaten                                   owner               sire  \
# 0                                R Bradley &amp; M Hammond        ACCLAMATION
# 1            1 1/4             Ontoawinner 8 and Partner 4         SHOWCASING
# 2                1                        Mrs Jenny Hadida             MAYSON
# 3               sh  Qatar Racing, D.Howden &amp; D.Redvers        TAGULA(IRE)
# 4               hd             Joseph Barton &amp; Partner        EQUIANO(FR)
# 5            1 1/4                Gary and Linnet Woodward        POETS VOICE
# 6               sh                              Mr K. Sohi        MEHMAS(IRE)
# 7            3 1/4                    Mr Hamdan Al Maktoum         SEPOY(AUS)
# 8               nk                         Mr B. J. Meehan            CAMACHO
# 9                2                            Mr P. Bowden  LOPE DE VEGA(IRE)
# 10             3/4              HP Racing The Princes Poet   BRAZEN BEAU(AUS)
#
#                    dam  OR   sp odds
# 0    GREEK EASTER(IRE)  82   10   []
# 1   SPRINGING BARONESS  85   11   []
# 2              ISRAFEL  82    5   []
# 3      FIXED GAZE(USA)  73  7.5   []
# 4        ELECTRIC FEEL  73    7   []
# 5          FILONA(IRE)  86   19   []
# 6        SENADORA(GER)  73    9   []
# 7          SAMAAH(IRE)  87  6.5   []
# 8       NEW MUSIC(IRE)  76   81   []
# 9    MINUTE LIMIT(IRE)  80   23   []
# 10               POESY  74    8   []
