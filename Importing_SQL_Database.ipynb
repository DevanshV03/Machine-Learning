# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 217.9 kB/s eta 0:00:55
#      --------------------------------------- 0.0/11.9 MB 217.9 kB/s eta 0:00:55
#      --------------------------------------- 0.1/11.9 MB 217.9 kB/s eta 0:00:55
#      --------------------------------------- 0.1/11.9 MB 204.8 kB/s eta 0:00:58
#      --------------------------------------- 0.1/11.9 MB 204.8 kB/s eta 0:00:58
#      --------------------------------------- 0.1/11.9 MB 284.4 kB/s eta 0:00:42
#       -------------------------------------- 0.2/11.9 MB 364.0 kB/s eta 0:00:33
#       -------------------------------------- 0.2/11.9 MB 364.0 kB/s eta 0:00:33
#      - ------------------------------------- 0.3/11.9 MB 655.4 kB/s eta 0:00:18
# ...

# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.connect(host = 'localhost', user = 'root', password = '', database = 'world')

# %%
pd.read_sql_query('SELECT * FROM city WHERE ID > 500',conn)
# Out:
# C:\Users\devan\AppData\Local\Temp\ipykernel_9008\163255215.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM city WHERE ID > 500',conn)
#         ID        Name CountryCode    District  Population
# 0      501   Blackburn         GBR     England      140000
# 1      502     Newport         GBR       Wales      139000
# 2      503     Preston         GBR     England      135000
# 3      504   Stockport         GBR     England      132813
# 4      505     Norwich         GBR     England      124000
# ...    ...         ...         ...         ...         ...
# 3574  4075  Khan Yunis         PSE  Khan Yunis      123175
# 3575  4076      Hebron         PSE      Hebron      119401
# 3576  4077    Jabaliya         PSE  North Gaza      113901
# ...
